# %%
import pandas as pd
import dill

# %%
import os

notebook_dir = r'/Users/melih.gorgulu/Desktop/Projects/intent_recognition/notebooks'
project_dir = os.path.dirname(notebook_dir)
print("Notebook Directory:", notebook_dir)
print("Project Directory:", project_dir)
os.chdir(project_dir)
# Out:
# Notebook Directory: /Users/melih.gorgulu/Desktop/Projects/intent_recognition/notebooks
# Project Directory: /Users/melih.gorgulu/Desktop/Projects/intent_recognition

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# Make sure to import ClassificationSpacyLemmaTokenizer from the source code.
from src.services.models.aftercourt_tokenizer import ClassificationSpacyLemmaTokenizer

# %%
VEC_PATH = "/Users/melih.gorgulu/Desktop/Projects/intent_recognition/notebooks/after-court/models/vectorizers/05-12-2026_tf_idf_vectorizer_v1.dill"
DATA_PATH = "/Users/melih.gorgulu/Desktop/Projects/intent_recognition/notebooks/after-court/model_training_data/ladung/05-02-2026-ladung_training_data.csv"

# %%
tf_idf_vectorizer = dill.load(open(VEC_PATH, 'rb'))
data = pd.read_csv(DATA_PATH)

# %%
invoice = [1069,1072,1200, 1328, 2832, 3141,1320,1356, 3135, 175, 1322, 1337, 1349, 4005, 3709, 4004,33, 1339, 3142, 4008]
Vermögensverzeichnis = [1325,665,1326]

# %%
data.loc[invoice, 'is_ladung'] = False
# Out:
# 1069    fp_invoice
# 1072    fp_invoice
# 1200    fp_invoice
# 1328    fp_invoice
# 2832    fp_invoice
# 3141    fp_invoice
# 1320    fp_invoice
# 1356    fp_invoice
# 3135    fp_invoice
# 175     fp_invoice
# 1322    fp_invoice
# 1337    fp_invoice
# 1349    fp_invoice
# 4005    fp_invoice
# 3709    fp_invoice
# 4004    fp_invoice
# 33      fp_invoice
# 1339    fp_invoice
# 3142    fp_invoice
# 4008    fp_invoice
# Name: document_type, dtype: object

# %%
data.loc[invoice, 'document_type'] = 'fp_invoice'
data.loc[invoice, 'is_ladung'] = False


data.loc[Vermögensverzeichnis, 'document_type'] = 'vermögensverzeichnis'
data.loc[Vermögensverzeichnis, 'is_ladung'] = False

# %%
data
# Out:
#                                                    text  \
# 0     4070071 967072\nAntrag auf Erlass eines Pfändu...
# 1     Antrag auf Erlass eines Pfänd 070071 967072\nÜ...
# 2     Antrag auf Erlass eines Pfändun\n4070071 96707...
# 3     Antrag auf Erlass eines Pfändungs\n4 070071 96...
# 4     Antrag auf Erlass eines Pfändu\n4070071 967072...
# ...                                                 ...
# 5333  Nicole Wernicke\nHanauer Straße 44\nGerichtsvo...
# 5334  Obergerichtsvollzieher Kiermeier\nAmtsgericht ...
# 5335  Elvira Jugovic\nHindenburgstraße 45 Rgb.\nGeri...
# 5336  Vanessa Göldner\nAm alten Bahnhof 9 (vormals 1...
# 5337  Obergerichtsvollzieher Lars Kramer\nPostanschr...
#
#                                              object_key  \
# 0     01.02.2022/1643724050_Doc_01022022_000000001_1...
# 1     01.02.2022/1643724051_Doc_01022022_000000001_1...
# 2     01.02.2022/1643724052_Doc_01022022_000000001_1...
# 3     01.02.2022/1643724052_Doc_01022022_000000001_1...
# 4     01.02.2022/1643724053_Doc_01022022_000000001_1...
# ...                                                 ...
# 5333                                                NaN
# 5334                                                NaN
# 5335                                                NaN
# 5336                                                NaN
# 5337                                                NaN
#
#                       document_type  \
# 0     attachment_and_transfer_order
# 1     attachment_and_transfer_order
# 2     attachment_and_transfer_order
# 3     attachment_and_transfer_order
# 4     attachment_and_transfer_order
# ...                             ...
# 5333                     fp_invoice
# 5334                     fp_invoice
# 5335                     fp_invoice
# 5336                     fp_invoice
# 5337                     fp_invoice
#
#                                            cleaned_text data is_pfub  \
# 0     4070071 967072\nantrag auf erlass eines pfändu...  NaN   False
# 1     antrag auf erlass eines pfänd 070071 967072\nü...  NaN   False
# 2     antrag auf erlass eines pfändun\n4070071 96707...  NaN   False
# 3     antrag auf erlass eines pfändungs\n4 070071 96...  NaN   False
# 4     antrag auf erlass eines pfändu\n4070071 967072...  NaN   False
# ...                                                 ...  ...     ...
# 5333                                                NaN  NaN     NaN
# 5334                                                NaN  NaN     NaN
# 5335                                                NaN  NaN     NaN
# 5336                                                NaN  NaN     NaN
# 5337                                                NaN  NaN     NaN
#
#       is_ladung                                          tokenized  \
# 0         False  ['antrag', 'erlass', 'pfändung', 'überweisungs...
# 1         False  ['antrag', 'erlass', 'pfänd', 'überweisungsbes...
# 2         False  ['antrag', 'erlass', 'pfändun', 'überweisungsb...
# 3         False  ['antrag', 'erlass', 'pfändung', 'überweisungs...
# 4         False  ['antrag', 'erlass', 'pfändu', 'überweisungsbe...
# ...         ...                                                ...
# 5333      False                                                NaN
# 5334      False                                                NaN
# 5335      False                                                NaN
# 5336      False                                                NaN
# 5337      False                                                NaN
#
#                                             text_w_tags attachment_id s3_link  \
# 0     <PHONE> <NUMBER>\nantrag auf erlass eines pfän...           NaN     NaN
# 1     antrag auf erlass eines pfänd <NUMBER><PHONE>\...           NaN     NaN
# 2     antrag auf erlass eines pfändun\n<PHONE> <NUMB...           NaN     NaN
# 3     antrag auf erlass eines pfändungs\n<NUMBER> <N...           NaN     NaN
# 4     antrag auf erlass eines pfändu\n<PHONE> <NUMBE...           NaN     NaN
# ...                                                 ...           ...     ...
# 5333  nicole wernicke\nhanauer straße <NUMBER>\ngeri...           NaN     NaN
# 5334  obergerichtsvollzieher kiermeier\namtsgericht ...           NaN     NaN
# 5335  elvira jugovic\nhindenburgstraße <NUMBER> rgb....           NaN     NaN
# 5336  vanessa göldner\nam alten bahnhof <NUMBER> (vo...           NaN     NaN
# 5337  obergerichtsvollzieher lars kramer\npostanschr...           NaN     NaN
#
#      id_ladung
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 5333       NaN
# 5334       NaN
# 5335       NaN
# 5336       NaN
# 5337       NaN
#
# [5338 rows x 12 columns]

# %%
data['document_type'].value_counts()
# Out:
# document_type
# ladung_va                                 2028
# mail_attachments                          1006
# monierung_mb                               545
# attachment_and_transfer_order              539
# approved_seizure                           408
# court_inbox                                346
# fp_protocol                                219
# fp_invoice                                 158
# approved_attachment_and_transfer_order      60
# enforcement_order                           23
# contradiction                                3
# vermögensverzeichnis                         3
# Name: count, dtype: int64

# %%
data['is_ladung'].value_counts()
# Out:
# is_ladung
# False    3287
# True     2051
# Name: count, dtype: int64

# %%
data
# Out:
#                                                    text  \
# 0     4070071 967072\nAntrag auf Erlass eines Pfändu...
# 1     Antrag auf Erlass eines Pfänd 070071 967072\nÜ...
# 2     Antrag auf Erlass eines Pfändun\n4070071 96707...
# 3     Antrag auf Erlass eines Pfändungs\n4 070071 96...
# 4     Antrag auf Erlass eines Pfändu\n4070071 967072...
# ...                                                 ...
# 5333  Nicole Wernicke\nHanauer Straße 44\nGerichtsvo...
# 5334  Obergerichtsvollzieher Kiermeier\nAmtsgericht ...
# 5335  Elvira Jugovic\nHindenburgstraße 45 Rgb.\nGeri...
# 5336  Vanessa Göldner\nAm alten Bahnhof 9 (vormals 1...
# 5337  Obergerichtsvollzieher Lars Kramer\nPostanschr...
#
#                                              object_key  \
# 0     01.02.2022/1643724050_Doc_01022022_000000001_1...
# 1     01.02.2022/1643724051_Doc_01022022_000000001_1...
# 2     01.02.2022/1643724052_Doc_01022022_000000001_1...
# 3     01.02.2022/1643724052_Doc_01022022_000000001_1...
# 4     01.02.2022/1643724053_Doc_01022022_000000001_1...
# ...                                                 ...
# 5333                                                NaN
# 5334                                                NaN
# 5335                                                NaN
# 5336                                                NaN
# 5337                                                NaN
#
#                       document_type  \
# 0     attachment_and_transfer_order
# 1     attachment_and_transfer_order
# 2     attachment_and_transfer_order
# 3     attachment_and_transfer_order
# 4     attachment_and_transfer_order
# ...                             ...
# 5333                     fp_invoice
# 5334                     fp_invoice
# 5335                     fp_invoice
# 5336                     fp_invoice
# 5337                     fp_invoice
#
#                                            cleaned_text data is_pfub  \
# 0     4070071 967072\nantrag auf erlass eines pfändu...  NaN   False
# 1     antrag auf erlass eines pfänd 070071 967072\nü...  NaN   False
# 2     antrag auf erlass eines pfändun\n4070071 96707...  NaN   False
# 3     antrag auf erlass eines pfändungs\n4 070071 96...  NaN   False
# 4     antrag auf erlass eines pfändu\n4070071 967072...  NaN   False
# ...                                                 ...  ...     ...
# 5333                                                NaN  NaN     NaN
# 5334                                                NaN  NaN     NaN
# 5335                                                NaN  NaN     NaN
# 5336                                                NaN  NaN     NaN
# 5337                                                NaN  NaN     NaN
#
#       is_ladung                                          tokenized  \
# 0         False  ['antrag', 'erlass', 'pfändung', 'überweisungs...
# 1         False  ['antrag', 'erlass', 'pfänd', 'überweisungsbes...
# 2         False  ['antrag', 'erlass', 'pfändun', 'überweisungsb...
# 3         False  ['antrag', 'erlass', 'pfändung', 'überweisungs...
# 4         False  ['antrag', 'erlass', 'pfändu', 'überweisungsbe...
# ...         ...                                                ...
# 5333      False                                                NaN
# 5334      False                                                NaN
# 5335      False                                                NaN
# 5336      False                                                NaN
# 5337      False                                                NaN
#
#                                             text_w_tags attachment_id s3_link
# 0     <PHONE> <NUMBER>\nantrag auf erlass eines pfän...           NaN     NaN
# 1     antrag auf erlass eines pfänd <NUMBER><PHONE>\...           NaN     NaN
# 2     antrag auf erlass eines pfändun\n<PHONE> <NUMB...           NaN     NaN
# 3     antrag auf erlass eines pfändungs\n<NUMBER> <N...           NaN     NaN
# 4     antrag auf erlass eines pfändu\n<PHONE> <NUMBE...           NaN     NaN
# ...                                                 ...           ...     ...
# 5333  nicole wernicke\nhanauer straße <NUMBER>\ngeri...           NaN     NaN
# 5334  obergerichtsvollzieher kiermeier\namtsgericht ...           NaN     NaN
# 5335  elvira jugovic\nhindenburgstraße <NUMBER> rgb....           NaN     NaN
# 5336  vanessa göldner\nam alten bahnhof <NUMBER> (vo...           NaN     NaN
# 5337  obergerichtsvollzieher lars kramer\npostanschr...           NaN     NaN
#
# [5338 rows x 11 columns]

# %% [markdown]
# cross validation

# %%
data.shape[0]*0.2
# Out:
# 1067.6000000000001

# %%
X_text = data['text_w_tags']
y = data['is_ladung']
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
dataset = 1
for train_index, test_index in skf.split(X_text, y):
    X_train_text, X_test_text = X_text.iloc[train_index], X_text.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    print(f"Dataset {dataset}:")
    print(f"  Train size: {X_train_text.shape[0]} samples")
    print(f"  Test size: {X_test_text.shape[0]} samples")
    print(f"Train set is ladung dist: {y_train.value_counts(normalize=True)}")
    print(f"Test set is ladung dist: {y_test.value_counts(normalize=True)}")
    dataset += 1
# Out:
# Dataset 1:
#   Train size: 4270 samples
#   Test size: 1068 samples
# Train set is ladung dist: is_ladung
# False    0.615691
# True     0.384309
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.616105
# True     0.383895
# Name: proportion, dtype: float64
# Dataset 2:
#   Train size: 4270 samples
#   Test size: 1068 samples
# Train set is ladung dist: is_ladung
# False    0.615691
# True     0.384309
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.616105
# True     0.383895
# Name: proportion, dtype: float64
# Dataset 3:
#   Train size: 4270 samples
#   Test size: 1068 samples
# Train set is ladung dist: is_ladung
# False    0.615925
# True     0.384075
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.615169
# True     0.384831
# Name: proportion, dtype: float64
# Dataset 4:
#   Train size: 4271 samples
#   Test size: 1067 samples
# Train set is ladung dist: is_ladung
# False    0.615781
# True     0.384219
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.615745
# True     0.384255
# Name: proportion, dtype: float64
# Dataset 5:
#   Train size: 4271 samples
#   Test size: 1067 samples
# Train set is ladung dist: is_ladung
# False    0.615781
# True     0.384219
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.615745
# True     0.384255
# Name: proportion, dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score,recall_score,f1_score

X_text = data['text_w_tags']
y = data['is_ladung']

doc_types_to_preds = []

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
dataset = 1
for train_index, test_index in skf.split(X_text, y):
    X_train_text, X_test_text = X_text.iloc[train_index], X_text.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Vectorize text data
    X_train_tfidf = tf_idf_vectorizer.transform(X_train_text)
    X_test_tfidf = tf_idf_vectorizer.transform(X_test_text)
    # basic RF

    rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
    rf_classifier.fit(X_train_tfidf, y_train)
    
    y_pred_probs = rf_classifier.predict_proba(X_test_tfidf)[:, 1]
    
    
    document_types_test = data.loc[X_test_text.index, 'document_type']
    doc_type_to_pred = pd.DataFrame({
    'dataset': dataset,
    'document_type': document_types_test,
    'predicted_probs': y_pred_probs
    })
    doc_types_to_preds.append(doc_type_to_pred)
    
    y_pred = y_pred_probs >= 0.95
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    print("Dataset {}:".format(dataset))
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("\nClassification Report:")
    print(classification_report(y_test, y_pred))
    print("\nConfusion Matrix:")
    print(confusion_matrix(y_test, y_pred))
    print("\n" + "="*50 + "\n")
    
    dataset += 1
# Out:
# Dataset 1:
# Accuracy: 0.9728
# Precision: 1.0000
# Recall: 0.9293
# F1 Score: 0.9633
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.96      1.00      0.98       658
#         True       1.00      0.93      0.96       410
#
#     accuracy                           0.97      1068
#    macro avg       0.98      0.96      0.97      1068
# weighted avg       0.97      0.97      0.97      1068
#
#
# Confusion Matrix:
# [[658   0]
#  [ 29 381]]
#
# ==================================================
#
# Dataset 2:
# Accuracy: 0.9672
# Precision: 1.0000
# Recall: 0.9146
# F1 Score: 0.9554
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.95      1.00      0.97       658
#         True       1.00      0.91      0.96       410
#
#     accuracy                           0.97      1068
#    macro avg       0.97      0.96      0.96      1068
# weighted avg       0.97      0.97      0.97      1068
#
#
# Confusion Matrix:
# [[658   0]
#  [ 35 375]]
#
# ==================================================
#
# Dataset 3:
# Accuracy: 0.9841
# Precision: 1.0000
# Recall: 0.9586
# F1 Score: 0.9789
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.99       657
#         True       1.00      0.96      0.98       411
#
#     accuracy                           0.98      1068
#    macro avg       0.99      0.98      0.98      1068
# weighted avg       0.98      0.98      0.98      1068
#
#
# Confusion Matrix:
# [[657   0]
#  [ 17 394]]
#
# ==================================================
#
# Dataset 4:
# Accuracy: 0.9822
# Precision: 1.0000
# Recall: 0.9537
# F1 Score: 0.9763
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.99       657
#         True       1.00      0.95      0.98       410
#
#     accuracy                           0.98      1067
#    macro avg       0.99      0.98      0.98      1067
# weighted avg       0.98      0.98      0.98      1067
#
#
# Confusion Matrix:
# [[657   0]
#  [ 19 391]]
#
# ==================================================
#
# Dataset 5:
# Accuracy: 0.9784
# Precision: 1.0000
# Recall: 0.9439
# F1 Score: 0.9711
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98       657
#         True       1.00      0.94      0.97       410
#
#     accuracy                           0.98      1067
#    macro avg       0.98      0.97      0.98      1067
# weighted avg       0.98      0.98      0.98      1067
#
#
# Confusion Matrix:
# [[657   0]
#  [ 23 387]]
#
# ==================================================

# %%
indexes_to_check = []
for i in doc_types_to_preds:
    gt_ladung_pred_probs = i[i['document_type'] == 'ladung_va']['predicted_probs']
    low_prob_indexes = gt_ladung_pred_probs[gt_ladung_pred_probs < 0.70].index
    indexes_to_check.extend(low_prob_indexes)

# %% [markdown]
# [647, 936, 1069, 1072, 1200, 1325, 1328, 2382, 3141, 665, 671, 1320, 1356, 3103, 3135, 175, 1322, 1326, 1337, 1349, 2811, 4005, 640, 3709, 4004, 33, 1319, 1339, 3142, 4008]

# %%
print(indexes_to_check)
# Out:
# [647, 936, 1069, 1072, 1200, 1325, 1328, 2382, 3141, 665, 671, 1320, 1356, 3103, 3135, 175, 1322, 1326, 1337, 1349, 2811, 4005, 640, 3709, 4004, 33, 1319, 1339, 3142, 4008]

# %%
import boto3
import os

# Setup S3 client with specific profile
session = boto3.Session(profile_name='739275445236_DataScienceUser')
s3_client = session.client('s3')

# Create tmp_pdfs directory if it doesn't exist
tmp_dir = os.path.join(os.getcwd(), 'tmp_pdfs')
os.makedirs(tmp_dir, exist_ok=True)

print(f"{'='*80}")
print(f"Downloading PDFs to: {tmp_dir}")
print(f"{'='*80}\n")

# Download PDFs for false negative predictions
downloaded = 0
failed = 0

for idx in indexes_to_check:
    row = data.loc[idx]
    doc_type = row['document_type']
    key = row['object_key']
    s3_bucket = "pair-scanner"
    
    # Extract filename from key
    filename = os.path.basename(key)
    local_path = os.path.join(tmp_dir, filename)
    
    print(f"\n{'-'*80}")
    print(f"\033[1m\033[96m📄 Document {downloaded + failed + 1}/{len(indexes_to_check)}\033[0m")
    print(f"   \033[93mDatabase Index\033[0m       : \033[1m{idx}\033[0m")
    print(f"   \033[93mGT Document Type\033[0m     : {doc_type}")
    print(f"   \033[93mFilename\033[0m             : {filename}")
    print(f"   \033[93mS3 Path\033[0m              : s3://{s3_bucket}/{key}")
    
    try:
        s3_client.download_file(s3_bucket, key, local_path)
        print(f"   \033[92m✅ Status\033[0m            : Downloaded successfully")
        print(f"   \033[93mLocal Path\033[0m           : {local_path}")
        downloaded += 1
    except Exception as e:
        print(f"   \033[91m❌ Status\033[0m            : Failed")
        print(f"   \033[91mError\033[0m                : {e}")
        failed += 1
    
print(f"\n\033[1m{'='*80}\033[0m")
print(f"\033[1m\033[92mDownload Summary: {downloaded} succeeded\033[0m, \033[91m{failed} failed\033[0m")
print(f"\033[1m{'='*80}\033[0m")
# Out:
# ================================================================================
# Downloading PDFs to: /Users/melih.gorgulu/Desktop/Projects/intent_recognition/tmp_pdfs
# ================================================================================
#
#
# --------------------------------------------------------------------------------
#    Local Path           : /Users/melih.gorgulu/Desktop/Projects/intent_recognition/tmp_pdfs/ocr-v2_DR_II_719_24_Gl_Haft_Vermögensauskunft.PDF
#
# ================================================================================
# Download Summary: 30 succeeded, 0 failed
# ================================================================================

# %% [markdown]
# invoice:1069,1072,1200, 1328, 2832, 3141,1320,1356, 3135, 175, 1322, 1337, 1349, 4005, 3709, 4004,33, 1339, 3142, 4008
# Vermögensverzeichnis = 1325,665,1326
# sordum: 647, 1325,3709

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train_text, X_test_text, y_train, y_test = train_test_split(
    X_text, y, test_size=0.2, random_state=42, stratify=y
)

print(f"Train set size: {len(X_train_text)}, Test set size: {len(X_test_text)}")
print(f"Train set is ladung dist: {y_train.value_counts(normalize=True)}")
print(f"Test set is ladung dist: {y_test.value_counts(normalize=True)}")
# Out:
# Train set size: 4270, Test set size: 1068
# Train set is ladung dist: is_ladung
# False    0.615691
# True     0.384309
# Name: proportion, dtype: float64
# Test set is ladung dist: is_ladung
# False    0.616105
# True     0.383895
# Name: proportion, dtype: float64

# %%
X_train_tfidf = tf_idf_vectorizer.transform(X_train_text)
X_test_tfidf = tf_idf_vectorizer.transform(X_test_text)
# basic RF

from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_tfidf, y_train)

# %%
y_pred_probs = rf_classifier.predict_proba(X_test_tfidf)[:, 1]
document_types_test = data.loc[X_test_text.index, 'document_type']
doc_type_to_pred = pd.DataFrame({
    'document_type': document_types_test,
    'predicted_probs': y_pred_probs
})

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create subplots with 1 row and 2 columns
fig = make_subplots(
    rows=1, cols=2,
    subplot_titles=('Distribution of Predicted Probabilities by Document Type (Box Plot)',
                    'Distribution of Predicted Probabilities by Document Type (Violin Plot)')
)

# Get unique document types
doc_types = doc_type_to_pred['document_type'].unique()

# Add box plots
for doc_type in doc_types:
    data_subset = doc_type_to_pred[doc_type_to_pred['document_type'] == doc_type]
    fig.add_trace(
        go.Box(
            y=data_subset['predicted_probs'],
            name=doc_type,
            boxmean='sd'
        ),
        row=1, col=1
    )

# Add violin plots
for doc_type in doc_types:
    data_subset = doc_type_to_pred[doc_type_to_pred['document_type'] == doc_type]
    fig.add_trace(
        go.Violin(
            y=data_subset['predicted_probs'],
            name=doc_type,
            box_visible=True,
            meanline_visible=True
        ),
        row=1, col=2
    )

# Add threshold line to violin plot
fig.add_hline(
    y=0.95, 
    line_dash="dash", 
    line_color="red",
    annotation_text="Threshold (0.95)",
    annotation_position="right",
    col=2
)

# Update layout
fig.update_layout(
    height=500,
    width=1400,
    showlegend=True,
    title_text="Predicted Probabilities Analysis by Document Type"
)

# Update y-axes labels
fig.update_yaxes(title_text="Predicted Probability", row=1, col=1)
fig.update_yaxes(title_text="Predicted Probability", row=1, col=2)

fig.show()

# Summary statistics by document type
print("\nSummary Statistics by Document Type:")
print(doc_type_to_pred.groupby('document_type')['predicted_probs'].describe())

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, precision_score,recall_score,f1_score
y_pred = y_pred_probs >= 0.95
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)


print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

"""
    true negatives is :math:`C_{0,0}`, false negatives is :math:`C_{1,0}`, 
    true positives is :math:`C_{1,1}` and false positives is :math:`C_{0,1}
"""

# %%
import pandas as pd

# Create dataframe with predictions, actual values, and original indexes
results_df = pd.DataFrame({
    'index': y_test.index,
    'y_test': y_test.values,
    'y_pred': y_pred
})

results_df['FP'] = (results_df['y_test'] == 0) & (results_df['y_pred'] == True)
results_df['FN'] = (results_df['y_test'] == 1) & (results_df['y_pred'] == False)
print("Total fp:", results_df['FP'].sum())
print("Total fn:", results_df['FN'].sum())
fp = results_df[results_df['FP']]
fn = results_df[results_df['FN']]

# %%
model_fn_preds = data.loc[fn['index']].copy()

# Add predicted probabilities to model_fn_preds
# Create a mapping from test indices to predicted probabilities
prob_mapping = pd.Series(y_pred_probs, index=y_test.index)
model_fn_preds['predicted_prob'] = model_fn_preds.index.map(prob_mapping)

# %%
import boto3
import os

# Setup S3 client with specific profile
session = boto3.Session(profile_name='739275445236_DataScienceUser')
s3_client = session.client('s3')

# Create tmp_pdfs directory if it doesn't exist
tmp_dir = os.path.join(os.getcwd(), 'tmp_pdfs')
os.makedirs(tmp_dir, exist_ok=True)

print(f"{'='*80}")
print(f"Downloading False Negative PDFs to: {tmp_dir}")
print(f"Total False Negatives: {len(model_fn_preds)}")
print(f"{'='*80}\n")

# Download PDFs for false negative predictions
downloaded = 0
failed = 0

for idx, row in model_fn_preds.iterrows():
    predicted_prob = row['predicted_prob']
    doc_type = row['document_type']
    key = row['object_key']
    s3_bucket = "pair-scanner"
    
    # Extract filename from key
    filename = os.path.basename(key)
    local_path = os.path.join(tmp_dir, filename)
    
    print(f"\n{'-'*80}")
    print(f"\033[1m\033[96m📄 Document {downloaded + failed + 1}/{len(model_fn_preds)}\033[0m")
    print(f"   \033[93mDatabase Index\033[0m       : \033[1m{idx}\033[0m")
    print(f"   \033[93mGT Document Type\033[0m     : {doc_type}")
    print(f"   \033[93mPredicted Ladung Prob\033[0m: \033[1m{predicted_prob:.4f}\033[0m")
    print(f"   \033[93mFilename\033[0m             : {filename}")
    print(f"   \033[93mS3 Path\033[0m              : s3://{s3_bucket}/{key}")
    
    try:
        s3_client.download_file(s3_bucket, key, local_path)
        print(f"   \033[92m✅ Status\033[0m            : Downloaded successfully")
        print(f"   \033[93mLocal Path\033[0m           : {local_path}")
        downloaded += 1
    except Exception as e:
        print(f"   \033[91m❌ Status\033[0m            : Failed")
        print(f"   \033[91mError\033[0m                : {e}")
        failed += 1
    
print(f"\n\033[1m{'='*80}\033[0m")
print(f"\033[1m\033[92mDownload Summary: {downloaded} succeeded\033[0m, \033[91m{failed} failed\033[0m")
print(f"\033[1m{'='*80}\033[0m")

# %%
low_prob_indexes = model_fn_preds[model_fn_preds['predicted_prob'] < 0.6].index

# %%
low_prob_indexes

# %% [markdown]
# 1845,2146,3184,2152,2414,1344

# %%
# indexes= [1845,2146,3184,2152,2414,1344]
# data.loc[indexes,'document_type'] = 'fp_invoice'
# data.loc[indexes,'is_ladung'] = False
# data.reset_index(drop=True,inplace=True)
# data.to_csv(DATA_PATH,index=False)

# %%
fp

# %%
row = data.loc[1324]
doc_type = row['document_type']
key = row['object_key']
s3_bucket = "pair-scanner"

# Extract filename from key
filename = os.path.basename(key)
local_path = os.path.join(tmp_dir, filename)
s3_client.download_file(s3_bucket, key, local_path)
print(local_path)

# %% [markdown]
# # TODO
# # BURA
# 1) ladung ask dokumanlarini sor
# 2) Gelen infoya gore update et datasetini
# 3) tekrardan retrain yapip burda, baska hatali data var mi bak. varsa duzelt, yoksa devam
# 4) prob analysis yap
# 5) yeni modeli full data ile egit
# 6) prod update et
# 7) pfub icin invoice var mi yok mu o branch devam et
